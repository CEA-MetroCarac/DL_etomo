# %% [markdown]
# ### Training and restoration of simulated nanoparticles in a supervised way
#
# *This notebook presents the training and application of a supervised model for the restoration of simulated nanoparticles data which suffer from degradation artefacts because of a degraded acquisition. The data set consists of 600 2D images from simulated nanoparticles. The nanoparticles were already forward projected using tomosipo's Radon transform (0°:1°:180°), and reconstructed with limited number of projections in three scenarios using SIRT algorithm in order to mimic scenarios from possibly real experimental acquisitions of nanoparticles :*
# - -60°:2°:+60°
# - -60°:10°:+60°
# - -30°:2°:+30°
#
# *The DL model is trained to restore the SIRT reconstructions suffering from several reconstruction artefacts. The goal is to finally apply the train model for the restoration of a real data set with similar nanoparticles. The model is applied on 2D images only.*

# %%
import sys
sys.path.insert(0, '../../Src')
from model import model_unet
from utils import simplify, to8bit, l1_mssim_loss

import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from skimage.io import imread
from skimage.metrics import structural_similarity as ssim, peak_signal_noise_ratio as psnr
import torch
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
from einops import rearrange

dtype = torch.cuda.FloatTensor
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# #### Load the simulated data (500 for training, 50 for testing and 50 for validation) and create the data loaders.
#
# *Data/Simulated/Reconstructions contains reference SIRT reconstructions (simu_full.tif) and SIRT reconstructions for the three mentionned scenarios (simu_mw60s2, simu_mw60s10, simu_mw30s2). The datasets are splitted between train, test and validation data.*
#
# Acquisition case can be changed with the **ACQUISITION_CASE** parameter.

# %%
reference = imread('../../Data/Simulated/Reconstructions/simu_full.tif')

# 1, 2 or 3 corresponding to acquisition range -60:2:+60, -60:10:+60 and -30:2:+30 respectively
ACQUISITION_CASE = 3
paths = {
    1: "../../Data/Simulated/Reconstructions/simu_mw60s2.tif",
    2: "../../Data/Simulated/Reconstructions/simu_mw60s10.tif",
    3: "../../Data/Simulated/Reconstructions/simu_mw30s2.tif",
}

degraded = imread(paths[ACQUISITION_CASE])

degraded = rearrange(torch.from_numpy(degraded).type(dtype), 'n x y -> n 1 x y')
reference = rearrange(torch.from_numpy(reference).type(dtype), 'n x y -> n 1 x y')

ref_train, ref_valid, ref_test = reference[:500], reference[500:550], reference[550:]
deg_train, deg_valid, deg_test = degraded[:500], degraded[500:550], degraded[550:]

# %%
class myDataset(Dataset):
    def __init__(self, degraded_data, gt_data):
        self.degraded_data = degraded_data
        self.gt_data = gt_data

    def __len__(self):
        return self.degraded_data.shape[0]

    def __getitem__(self, idx):
        input_data = self.degraded_data[idx,:,:]
        ref_data = self.gt_data[idx,:,:]
        
        return input_data, ref_data

# Creation of the different data loaders
train_dataset = myDataset(deg_train, ref_train)
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)

valid_dataset = myDataset(deg_valid, ref_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=4, shuffle=True)

test_dataset = myDataset(deg_test, ref_test)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# #### Setup of the network, training parameters and training loop
#
# *Training parameter (epochs, learning rate) are set with the same values as in the article. The U-Net model is setup as described in the article. The mixed L1-MSSSIM loss is used for the training. The network is trained with the 500 training images and it uses 50 images for validation during training. The training and validation losses are computed and displayed after training.*

# %%
EPOCHS = 30
LR = 3e-4

ud_filters, skip_filters = [16,32,64,128], [4,8,16,32]
n_scale = len(ud_filters)
model = model_unet(input_shape=1,
            down_filters=ud_filters, up_filters=ud_filters, skip_filters=skip_filters,
            down_kernels=[3]*len(ud_filters), up_kernels=[3]*len(ud_filters), skip_kernels=[1]*len(ud_filters),
            up_mode='bilinear', down_mode='stride', pad_mode='reflect'
           ).to('cuda').type(dtype)

optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# %%
global_train_loss = []
global_val_loss = []

for epoch in range(EPOCHS):

    model.train()

    epoch_loss = []
    
    loop = tqdm(train_dataloader, desc=f'Epoch {epoch+1}/{EPOCHS}')
    for train_data, gt_train_data in loop:

        for param in model.parameters():
            param.grad = None

        out = model(train_data)

        loss = l1_mssim_loss(out, gt_train_data, alpha=0.4)

        loss.backward()
        optimizer.step()
        
        epoch_loss.append(loss.item())

    global_train_loss.append(np.mean(epoch_loss))

    model.eval()
    val_epoch_loss = []
    with torch.no_grad():
        for val_data, gt_val_data in valid_dataloader:
            val_out = model(val_data)
            val_loss = l1_mssim_loss(val_out, gt_val_data)
            val_epoch_loss.append(val_loss.item())
        global_val_loss.append(np.mean(val_epoch_loss))

    print(f'Training loss {global_train_loss[-1]:.3f} - Validation loss {global_val_loss[-1]:.3f}')
# Out:
# Epoch 1/30: 100%|██████████| 125/125 [00:06<00:00, 18.85it/s]
# Training loss 0.020 - Validation loss 0.016
# Epoch 2/30: 100%|██████████| 125/125 [00:06<00:00, 18.87it/s]
# Training loss 0.012 - Validation loss 0.012
# Epoch 3/30: 100%|██████████| 125/125 [00:06<00:00, 18.88it/s]
# Training loss 0.011 - Validation loss 0.011
# Epoch 4/30: 100%|██████████| 125/125 [00:06<00:00, 18.87it/s]
# Training loss 0.010 - Validation loss 0.010
# Epoch 5/30: 100%|██████████| 125/125 [00:06<00:00, 18.87it/s]
# Training loss 0.009 - Validation loss 0.011
# Epoch 6/30: 100%|██████████| 125/125 [00:06<00:00, 18.88it/s]
# Training loss 0.009 - Validation loss 0.010
# Epoch 7/30: 100%|██████████| 125/125 [00:06<00:00, 18.88it/s]
# Training loss 0.008 - Validation loss 0.009
# Epoch 8/30: 100%|██████████| 125/125 [00:06<00:00, 18.92it/s]
# Training loss 0.008 - Validation loss 0.009
# Epoch 9/30: 100%|██████████| 125/125 [00:06<00:00, 18.77it/s]
# Training loss 0.007 - Validation loss 0.009
# Epoch 10/30: 100%|██████████| 125/125 [00:06<00:00, 19.22it/s]
# Training loss 0.007 - Validation loss 0.013
# Epoch 11/30: 100%|██████████| 125/125 [00:06<00:00, 19.22it/s]
# Training loss 0.007 - Validation loss 0.008
# Epoch 12/30: 100%|██████████| 125/125 [00:06<00:00, 19.21it/s]
# Training loss 0.006 - Validation loss 0.011
# Epoch 13/30: 100%|██████████| 125/125 [00:06<00:00, 19.21it/s]
# Training loss 0.006 - Validation loss 0.009
# Epoch 14/30: 100%|██████████| 125/125 [00:06<00:00, 19.26it/s]
# Training loss 0.006 - Validation loss 0.035
# Epoch 15/30: 100%|██████████| 125/125 [00:06<00:00, 19.22it/s]
# Training loss 0.006 - Validation loss 0.009
# Epoch 16/30: 100%|██████████| 125/125 [00:06<00:00, 19.17it/s]
# Training loss 0.006 - Validation loss 0.008
# Epoch 17/30: 100%|██████████| 125/125 [00:06<00:00, 19.18it/s]
# Training loss 0.005 - Validation loss 0.011
# Epoch 18/30: 100%|██████████| 125/125 [00:06<00:00, 19.10it/s]
# Training loss 0.005 - Validation loss 0.010
# Epoch 19/30: 100%|██████████| 125/125 [00:06<00:00, 18.88it/s]
# Training loss 0.005 - Validation loss 0.008
# Epoch 20/30: 100%|██████████| 125/125 [00:06<00:00, 18.88it/s]
# Training loss 0.005 - Validation loss 0.009
# Epoch 21/30: 100%|██████████| 125/125 [00:06<00:00, 18.89it/s]
# Training loss 0.005 - Validation loss 0.008
# Epoch 22/30: 100%|██████████| 125/125 [00:06<00:00, 18.84it/s]
# Training loss 0.005 - Validation loss 0.011
# Epoch 23/30: 100%|██████████| 125/125 [00:06<00:00, 18.75it/s]
# Training loss 0.005 - Validation loss 0.008
# Epoch 24/30: 100%|██████████| 125/125 [00:06<00:00, 18.75it/s]
# Training loss 0.005 - Validation loss 0.025
# Epoch 25/30: 100%|██████████| 125/125 [00:06<00:00, 18.76it/s]
# Training loss 0.005 - Validation loss 0.009
# Epoch 26/30: 100%|██████████| 125/125 [00:06<00:00, 18.76it/s]
# Training loss 0.005 - Validation loss 0.016
# Epoch 27/30: 100%|██████████| 125/125 [00:06<00:00, 18.16it/s]
# Training loss 0.005 - Validation loss 0.008
# Epoch 28/30: 100%|██████████| 125/125 [00:07<00:00, 17.21it/s]
# Training loss 0.005 - Validation loss 0.011
# Epoch 29/30: 100%|██████████| 125/125 [00:08<00:00, 15.15it/s]
# Training loss 0.005 - Validation loss 0.018
# Epoch 30/30: 100%|██████████| 125/125 [00:07<00:00, 16.21it/s]
# Training loss 0.005 - Validation loss 0.023

# %%
plt.figure(figsize=(9,4))
plt.plot(list(range(1,EPOCHS+1)), global_train_loss, label='train')
plt.plot(list(range(1,EPOCHS+1)), global_val_loss, label='valid')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss value')
plt.title('Evolution of the training and validation loss during the training of the model')
# Out:
# Text(0.5, 1.0, 'Evolution of the training and validation loss during the training of the model')

# %% [markdown]
# ##### Saving of the model weights after training
#
# *The weigths of the trained model can be saved for later use or the pre-trained model saved can be used directly. Default directory is **Temp_out**.*

# %%
OUT_PATH = Path("../../Temp_out")
if not OUT_PATH.is_dir():
    OUT_PATH.mkdir()
torch.save(model.state_dict(), f'{OUT_PATH}/model_trained_{ACQUISITION_CASE}.pth')

# %% [markdown]
# #### Application of the trained model to test data not used during training, and computation of image quality metrics.
#
# *There is the choice to use a pretrained model already saved.*

# %%
'''
Don't use if THE model is already trained in the notebook
Load the last model saved in the 'Temp_out' directory
'''
ud_filters, skip_filters = [32,64,128], [8,16,32]
n_scale = len(ud_filters)
model = model_unet(input_shape=1,
            down_filters=ud_filters, up_filters=ud_filters, skip_filters=skip_filters,
            down_kernels=[3]*len(ud_filters), up_kernels=[3]*len(ud_filters), skip_kernels=[1]*len(ud_filters),
            up_mode='bilinear', down_mode='stride', pad_mode='reflect'
           ).to('cuda').type(dtype)

model.load_state_dict(torch.load(f'../../Trained_models/model_trained_{ACQUISITION_CASE}.pth'))

# %%
# Application of the trained model to each of the test data
test_reco_list = []
for test_data, _ in test_dataloader:
    out_test = model(test_data)
    test_reco_list.append(simplify(out_test))

# %%
# Chose image index in [0 - 50] from the test data set
data_index = 15

fig, ((ax0, ax1, ax2)) = plt.subplots(1, 3, figsize = (12,8))
ax0.imshow(simplify(deg_test[data_index,:,:]))
ax0.set_title('Degraded SIRT reconstruction')
ax1.imshow(simplify(test_reco_list[data_index]))
ax1.set_title('U-Net restoration from SIRT')
ax2.imshow(simplify(ref_test[data_index]))
ax2.set_title('SIRT reference reconstruction')
# Out:
# Text(0.5, 1.0, 'SIRT reference reconstruction')

# %%
# Computation of image quality metrics on the SIRT reconstruction and the restored images

ref = to8bit(ref_test[data_index])
sirt = to8bit(deg_test[data_index,:,:])
unet = to8bit(test_reco_list[data_index])

ssim_sirt = ssim(ref, sirt)
psnr_sirt = psnr(ref, sirt)
ssim_unet = ssim(ref, unet)
psnr_unet = psnr(ref, unet)

print('Degraded SIRT')
print(f'SSIM: {ssim_sirt:.4f} - PSNR: {psnr_sirt:.4f}')
print('Restored')
print(f'SSIM: {ssim_unet:.4f} - PSNR: {psnr_unet:.4f}')
# Out:
# Degraded SIRT
# SSIM: 0.7490 - PSNR: 24.3880
# Restored
# SSIM: 0.0726 - PSNR: 17.1132
